# %%
from os import chdir
chdir('../')

# %%
from lib.app import Q

# %%
from lib.helpers.application_helper import test_function

# %%
for _ in range(1000):
    Q.enqueue(test_function)

# %%
import psycopg2
import numpy as np
from os import environ
conn = psycopg2.connect(dbname='postgres', user='postgres', host=environ['REDHAT_POSTGRES_1_PORT_5432_TCP_ADDR'])
cur = conn.cursor()

# %%
cur = conn.cursor()
cur.execute("SELECT act_id FROM action WHERE act_outcome = True OR act_outcome = False")

# %%
import lib.helpers.database_helper as dh

# %%
act_id = cur.fetchone()[0]
while act_id:
    Q.enqueue(dh.one_hot_encode_row, act_id)
    act_id = cur.fetchone()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-d55ff0e4b11c> in <module>()
#       2 while act_id:
#       3     Q.enqueue(dh.one_hot_encode_row, act_id)
# ----> 4     act_id = cur.fetchone()[0]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
for _ in range(100):
    act_id = cur.fetchone()[0]
    Q.enqueue(dh.one_hot_encode_row, act_id)

# %%
cur.execute("INSERT into one_hot_ppl_act (act_id, act_date, act_category_type_4, act_char_1_none, act_char_2_none, act_char_3_none, act_char_4_none, act_char_5_none, act_char_6_none, act_char_7_none, act_char_8_none, act_char_9_none, act_char_10, act_outcome, people_id, ppl_char_1_type_2, ppl_group_1, ppl_char_2_type_2, ppl_date, ppl_char_3_type_5, ppl_char_4_type_5, ppl_char_5_type_5, ppl_char_6_type_3, ppl_char_7_type_11, ppl_char_8_type_2, ppl_char_9_type_2, ppl_char_10, ppl_char_11, ppl_char_12, ppl_char_13, ppl_char_14, ppl_char_15, ppl_char_16, ppl_char_17, ppl_char_18, ppl_char_19, ppl_char_20, ppl_char_21, ppl_char_22, ppl_char_23, ppl_char_24, ppl_char_25, ppl_char_26, ppl_char_27, ppl_char_28, ppl_char_29, ppl_char_30, ppl_char_31, ppl_char_32, ppl_char_33, ppl_char_34, ppl_char_35, ppl_char_36, ppl_char_37, ppl_char_38) VALUES ('act2_1734928', '2023-08-26 00:00:00', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'type 76', 'False', 'ppl_100', 'True', 'group 17304', 'True', '2021-06-29 00:00:00', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'False', '36.0')")

# %%
cur.execute("SELECT * FROM one_hot_ppl_act")

# %%
cur.fetchall()
# Out:
# [('ppl_100',
#   'group 17304',
#   datetime.datetime(2021, 6, 29, 0, 0),
#   datetime.datetime(2023, 8, 26, 0, 0),
#   'act2_1734928',
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
# ...
