# %%
import psycopg2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from os import environ
conn = psycopg2.connect(dbname='postgres', user='postgres', host=environ['POSTGRES_1_PORT_5432_TCP_ADDR'])
cur = conn.cursor()

# %%
fields = """a.act_id, a.act_date, a.act_category,
            a.act_char_1, a.act_char_2, a.act_char_3,
            a.act_char_4, a.act_char_5, a.act_char_6,
            a.act_char_7, a.act_char_8, a.act_char_9,
            a.act_char_10, a.act_outcome, p.people_id,
            p.ppl_char_1, p.ppl_group_1, p.ppl_char_2,
            p.ppl_date, p.ppl_char_3, p.ppl_char_4,
            p.ppl_char_5, p.ppl_char_6, p.ppl_char_7,
            p.ppl_char_8, p.ppl_char_9, p.ppl_char_10,
            p.ppl_char_11, p.ppl_char_12, p.ppl_char_13,
            p.ppl_char_14, p.ppl_char_15, p.ppl_char_16,
            p.ppl_char_17, p.ppl_char_18, p.ppl_char_19,
            p.ppl_char_20, p.ppl_char_21, p.ppl_char_22,
            p.ppl_char_23, p.ppl_char_24, p.ppl_char_25,
            p.ppl_char_26, p.ppl_char_27, p.ppl_char_28,
            p.ppl_char_29, p.ppl_char_30, p.ppl_char_31,
            p.ppl_char_32, p.ppl_char_33, p.ppl_char_34,
            p.ppl_char_35, p.ppl_char_36, p.ppl_char_37,
            p.ppl_char_38"""

# %%
cur.execute("""SELECT act_id 
            FROM action 
            WHERE act_outcome = True OR act_outcome = False 
            LIMIT 10000""")
sample_ids = cur.fetchall()
sample_ids = [id[0] for id in sample_ids]

# %%
ppl_actions = []
for this_id in sample_ids:
    cur.execute("""
    SELECT {}
    FROM action a, people p 
    WHERE a.people_id = p.people_id AND a.act_id = '{}'
    """.format(fields, this_id))
ppl_actions.append(cur.fetchall()[0])

# %%
df = pd.DataFrame.from_records(ppl_actions, columns=fields.split(','))
df.head()
# Out:
#        a.act_id  a.act_date  a.act_category \n            a.act_char_1  \
# 0  act2_2564972  2023-04-13         type 02                       None
# 1  act2_2564972  2023-04-13         type 02                       None
# 2  act2_2564972  2023-04-13         type 02                       None
# 3  act2_2564972  2023-04-13         type 02                       None
# 4  act2_2564972  2023-04-13         type 02                       None
#
#    a.act_char_2  a.act_char_3 \n            a.act_char_4  a.act_char_5  \
# 0          None          None                       None          None
# 1          None          None                       None          None
# 2          None          None                       None          None
# 3          None          None                       None          None
# 4          None          None                       None          None
#
#    a.act_char_6 \n            a.act_char_7             ...              \
# 0          None                       None             ...
# 1          None                       None             ...
# 2          None                       None             ...
# 3          None                       None             ...
# 4          None                       None             ...
#
#   \n            p.ppl_char_29  p.ppl_char_30  p.ppl_char_31  \
# 0                       False          False          False
# 1                       False          False          False
# 2                       False          False          False
# 3                       False          False          False
# 4                       False          False          False
#
#   \n            p.ppl_char_32  p.ppl_char_33  p.ppl_char_34  \
# 0                        True          False           True
# 1                        True          False           True
# 2                        True          False           True
# 3                        True          False           True
# 4                        True          False           True
#
#   \n            p.ppl_char_35  p.ppl_char_36  p.ppl_char_37  \
# 0                       False           True           True
# 1                       False           True           True
# 2                       False           True           True
# 3                       False           True           True
# 4                       False           True           True
#
#   \n            p.ppl_char_38
# 0                        95.0
# 1                        95.0
# 2                        95.0
# 3                        95.0
# 4                        95.0
#
# [5 rows x 55 columns]

# %%
from sklearn.decomposition import PCA 
pca = PCA(6)
pca.fit(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-6ec357e7d7b3> in <module>()
#       1 from sklearn.decomposition import PCA
#       2 pca = PCA(6)
# ----> 3 pca.fit(df)
#
# /opt/conda/lib/python3.5/site-packages/sklearn/decomposition/pca.py in fit(self, X, y)
#     222             Returns the instance itself.
#     223         """
# --> 224         self._fit(X)
#     225         return self
#     226
#
# /opt/conda/lib/python3.5/site-packages/sklearn/decomposition/pca.py in _fit(self, X)
#     266             requested.
#     267         """
# --> 268         X = check_array(X)
#     269         n_samples, n_features = X.shape
#     270         X = as_float_array(X, copy=self.copy)
#
# /opt/conda/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     391         # make sure we acually converted to numeric:
#     392         if dtype_numeric and array.dtype.kind == "O":
# --> 393             array = array.astype(np.float64)
#     394         if not allow_nd and array.ndim >= 3:
#     395             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: 'type 02'
