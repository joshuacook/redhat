# %%
# %%bash
# env
# Out:
# REDHAT_POSTGRES_1_PORT_5432_TCP_PROTO=tcp
# POSTGRES_PORT=tcp://172.17.0.13:5432
# REDHAT_REDIS_1_ENV_REDIS_DOWNLOAD_SHA1=92d6d93ef2efc91e595c8bf578bf72baff397507
# REDIS_PORT_6379_TCP_PROTO=tcp
# REDIS_ENV_REDIS_DOWNLOAD_URL=http://download.redis.io/releases/redis-3.2.3.tar.gz
# HOSTNAME=17315ba6dda8
# SPARK_HOME=/usr/local/spark
# REDIS_ENV_REDIS_DOWNLOAD_SHA1=92d6d93ef2efc91e595c8bf578bf72baff397507
# TERM=xterm-color
# NB_USER=jovyan
# SHELL=/bin/bash
# CLICOLOR=1
# REDHAT_POSTGRES_1_PORT_5432_TCP_PORT=5432
# REDIS_1_PORT_6379_TCP=tcp://172.17.0.12:6379
# POSTGRES_1_ENV_PG_VERSION=9.5.4-1.pgdg80+1
# POSTGRES_1_ENV_GOSU_VERSION=1.7
# POSTGRES_ENV_LANG=en_US.utf8
# SPARK_OPTS=--driver-java-options=-Xms1024M --driver-java-options=-Xmx4096M --driver-java-options=-Dlog4j.logLevel=info
# REDIS_NAME=/redhat_jupyter_1/redis
# REDIS_1_PORT_6379_TCP_PORT=6379
# LC_ALL=en_US.UTF-8
# POSTGRES_ENV_GOSU_VERSION=1.7
# REDHAT_REDIS_1_PORT_6379_TCP=tcp://172.17.0.12:6379
# ...
