# %%
# %%bash
# env
# Out:
# REDHAT_POSTGRES_1_PORT_5432_TCP_PROTO=tcp
# REDHAT_REDIS_1_ENV_REDIS_DOWNLOAD_SHA1=f0fe685cbfdb8c2d8c74613ad8a5a5f33fba40c9
# POSTGRES_PORT=tcp://172.17.0.5:5432
# REDIS_ENV_REDIS_DOWNLOAD_URL=http://download.redis.io/releases/redis-3.2.4.tar.gz
# REDIS_PORT_6379_TCP_PROTO=tcp
# HOSTNAME=de181dc2537c
# REDIS_ENV_no_proxy=*.local, 169.254/16
# REDIS_ENV_REDIS_DOWNLOAD_SHA1=f0fe685cbfdb8c2d8c74613ad8a5a5f33fba40c9
# TERM=xterm-color
# SHELL=/bin/bash
# NB_USER=jovyan
# CLICOLOR=1
# REDHAT_POSTGRES_1_PORT_5432_TCP_PORT=5432
# REDIS_1_ENV_no_proxy=*.local, 169.254/16
# REDIS_1_PORT_6379_TCP=tcp://172.17.0.4:6379
# POSTGRES_1_ENV_PG_VERSION=9.6.0-1.pgdg80+1
# POSTGRES_1_ENV_GOSU_VERSION=1.7
# POSTGRES_ENV_LANG=en_US.utf8
# REDIS_NAME=/redhat_jupyter_1/redis
# REDIS_1_PORT_6379_TCP_PORT=6379
# POSTGRES_ENV_GOSU_VERSION=1.7
# LC_ALL=en_US.UTF-8
# REDHAT_REDIS_1_PORT_6379_TCP=tcp://172.17.0.4:6379
# REDIS_PORT_6379_TCP_ADDR=172.17.0.4
# REDIS_1_PORT=tcp://172.17.0.4:6379
# ...
